# %% [markdown]
# # Boston Housing Price Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing = pd.read_csv("Data/boston.csv").drop("Unnamed: 0", axis=1)

# %%
housing.isna().values.any()
# Out:
# False

# %%
housing.duplicated().values.any()
# Out:
# False

# %%
housing.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO       B  LSTAT  PRICE
# 0  296.0     15.3  396.90   4.98   24.0
# 1  242.0     17.8  396.90   9.14   21.6
# 2  242.0     17.8  392.83   4.03   34.7
# 3  222.0     18.7  394.63   2.94   33.4
# 4  222.0     18.7  396.90   5.33   36.2

# %%
housing.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# ### Understand the Boston House Price Dataset
#
# ---------------------------
#
# **Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. The Median Value (attribute 14) is the target.
#
#     :Attribute Information (in order):
#         1. CRIM     per capita crime rate by town
#         2. ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         3. INDUS    proportion of non-retail business acres per town
#         4. CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         5. NOX      nitric oxides concentration (parts per 10 million)
#         6. RM       average number of rooms per dwelling
#         7. AGE      proportion of owner-occupied units built prior to 1940
#         8. DIS      weighted distances to five Boston employment centres
#         9. RAD      index of accessibility to radial highways
#         10. TAX      full-value property-tax rate per $10,000
#         11. PTRATIO  pupil-teacher ratio by town
#         12. B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         13. LSTAT    % lower status of the population
#         14. PRICE     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of [UCI ML housing dataset](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/). This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University. You can find the [original research paper here](https://deepblue.lib.umich.edu/bitstream/handle/2027.42/22636/0000186.pdf?sequence=1&isAllowed=y).

# %%
housing.hist(bins=50, figsize=(12, 8))
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(housing.drop(["PRICE"], axis=1), housing.PRICE, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lreg = LinearRegression()

# %%
lreg.fit(scaler.fit_transform(start_X_train.drop("expensiveness", axis=1)), start_y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(lreg.predict(scaler.fit_transform(start_X_test.drop("expensiveness", axis=1))), start_y_test, squared=False)
# Out:
# 4.3294778283685424

# %% [markdown]
# ## Try using startified results do it causes any difference

# %%
housing["expensiveness"] = pd.cut(housing["PRICE"], bins=[0., 10., 20., 30., 40., np.inf], labels=[0, 1, 2, 3, 4])

# %%
start_X_train, start_X_test, start_y_train, start_y_test = train_test_split(housing.drop(["PRICE"], axis=1), housing.PRICE, test_size=0.2, random_state=42, stratify=housing.expensiveness)

# %%
start_X_test["expensiveness"].value_counts().sort_index().plot.bar(rot=0, grid=True)
plt.xlabel("expensiveness")
plt.ylabel("Number of homes")
plt.show()

# %%
for col in housing.columns:
    housing.plot(kind="scatter", x=col, y='PRICE', c="AGE", cmap="jet", colorbar=True)

# %% [markdown]
# ## Look for Corelations

# %%
housing.drop("expensiveness", axis=1, inplace=True)

# %%
coor_matrix = housing.corr()

# %%
coor_matrix.PRICE.sort_values(ascending=False)
# Out:
# PRICE      1.000000
# RM         0.695360
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRIM      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Name: PRICE, dtype: float64

# %% [markdown]
# ## Try scaling the features and see if there is any difference inbetween them

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
start_X_train.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 362  3.67822   0.0  18.10   0.0  0.770  5.362  96.2  2.1036  24.0  666.0
# 36   0.09744   0.0   5.96   0.0  0.499  5.841  61.4  3.3779   5.0  279.0
# 327  0.24103   0.0   7.38   0.0  0.493  6.083  43.7  5.4159   5.0  287.0
# 284  0.00906  90.0   2.97   0.0  0.400  7.088  20.8  7.3073   1.0  285.0
# 54   0.01360  75.0   4.00   0.0  0.410  5.888  47.6  7.3197   3.0  469.0
#
#      PTRATIO       B  LSTAT expensiveness
# 362     20.2  380.79  10.19             2
# 36      19.2  377.56  11.41             1
# 327     19.6  396.90  12.79             2
# 284     15.3  394.72   7.85             3
# 54      21.1  396.90  14.80             1

# %%
from sklearn.metrics.pairwise import rbf_kernel
from sklearn.preprocessing import FunctionTransformer

# %%
transformer = FunctionTransformer(np.log)

# %%
log_housing = transformer.fit_transform(start_X_train, start_y_train)
# Out:
# C:\Users\abhis\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)

# %%
start_X_test.drop("expensiveness", axis=1, inplace=True)

# %%
start_X_train.drop("expensiveness", axis=1, inplace=True)

# %%
log_housing.replace([-np.inf, 0], [0, 1], inplace=True)

# %%
log_housing.head()
# Out:
#          CRIM        ZN     INDUS  CHAS       NOX        RM       AGE  \
# 362  1.302429      -inf  2.895912  -inf -0.261365  1.679337  4.566429
# 36  -2.328518      -inf  1.785070  -inf -0.695149  1.764902  4.117410
# 327 -1.422834      -inf  1.998774  -inf -0.707246  1.805498  3.777348
# 284 -4.703886  4.499810  1.088562  -inf -0.916291  1.958403  3.034953
# 54  -4.297685  4.317488  1.386294  -inf -0.891598  1.772916  3.862833
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# 362  0.743650  3.178054  6.501290  3.005683  5.942248  2.321407
# 36   1.217254  1.609438  5.631212  2.954910  5.933729  2.434490
# 327  1.689339  1.609438  5.659482  2.975530  5.983684  2.548664
# 284  1.988874  0.000000  5.652489  2.727853  5.978177  2.060514
# 54   1.990569  1.098612  6.150603  3.049273  5.983684  2.694627

# %% [markdown]
# ## Pipelined Approach

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
preprocessing = Pipeline(
    [
        ("impude", SimpleImputer(strategy="median")),
        ("scale", StandardScaler()),
        ("log", FunctionTransformer(np.log, feature_names_out="one-to-one"))
    ]
)

# %%
transformed_data = pd.DataFrame(preprocessing.fit_transform(start_X_train), columns=preprocessing.get_feature_names_out())
# Out:
# C:\Users\abhis\anaconda3\Lib\site-packages\sklearn\preprocessing\_function_transformer.py:310: RuntimeWarning: invalid value encountered in log
#   return func(X, **(kw_args if kw_args else {}))

# %%
transformed_data
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -5.753036       NaN  0.015773       NaN  0.574329       NaN -0.021951
# 1         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3         NaN  1.225467       NaN       NaN       NaN  0.164049       NaN
# 4         NaN  1.013576       NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 399       NaN       NaN       NaN       NaN       NaN       NaN -0.360641
# 400       NaN       NaN       NaN       NaN       NaN -1.594879       NaN
# 401       NaN       NaN       NaN       NaN       NaN       NaN -0.524532
# 402       NaN       NaN       NaN       NaN       NaN  0.813176       NaN
# 403       NaN       NaN  0.208130  1.338399  0.962208       NaN -0.692172
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# ...

# %% [markdown]
# # The real Start

# %% [markdown]
# ## Divide the data with proper distribution

# %%
housing["expensiveness"] = pd.cut(housing["PRICE"], bins=[0., 10., 20., 30., 40., np.inf], labels=[0, 1, 2, 3, 4])

# %%
X_train, X_test, y_train, y_test = train_test_split(housing.drop(["PRICE", "expensiveness"], axis=1), housing.PRICE, test_size=0.2, random_state=42, stratify=housing.expensiveness)

# %%
log_trans = FunctionTransformer(np.log, inverse_func=np.exp, feature_names_out="one-to-one")
replacer = FunctionTransformer(lambda X: X.replace([-np.inf, 0], [0, 1]), feature_names_out="one-to-one")

# %%
X_train.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
preprocessing = ColumnTransformer(
    [
        ("log", log_trans, X_train.columns),
        ("replacer", replacer, X_train.columns)
    ]
)

# %%
# transformed_data = pd.DataFrame(preprocessing.fit_transform(X_train), columns=preprocessing.get_feature_names_out())
# Out:
# C:\Users\abhis\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# C:\Users\abhis\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)

# %%
# transformed_data.head()
# Out:
#    log__CRIM   log__ZN  log__INDUS  log__CHAS  log__NOX   log__RM  log__AGE  \
# 0   1.302429      -inf    2.895912       -inf -0.261365  1.679337  4.566429
# 1  -2.328518      -inf    1.785070       -inf -0.695149  1.764902  4.117410
# 2  -1.422834      -inf    1.998774       -inf -0.707246  1.805498  3.777348
# 3  -4.703886  4.499810    1.088562       -inf -0.916291  1.958403  3.034953
# 4  -4.297685  4.317488    1.386294       -inf -0.891598  1.772916  3.862833
#
#    log__DIS  log__RAD  log__TAX  ...  replacer__CHAS  replacer__NOX  \
# 0  0.743650  3.178054  6.501290  ...             1.0          0.770
# 1  1.217254  1.609438  5.631212  ...             1.0          0.499
# 2  1.689339  1.609438  5.659482  ...             1.0          0.493
# 3  1.988874  0.000000  5.652489  ...             1.0          0.400
# 4  1.990569  1.098612  6.150603  ...             1.0          0.410
#
#    replacer__RM  replacer__AGE  replacer__DIS  replacer__RAD  replacer__TAX  \
# ...

# %% [markdown]
# ## Linear Model

# %%
from sklearn.pipeline import make_pipeline

# %%
lin_reg = make_pipeline(
    preprocessing,
    LinearRegression()
)

# %%
lin_reg.fit(X_train, y_train)
# Out:
# C:\Users\abhis\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# C:\Users\abhis\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 lin_reg.fit(X_train, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\pipeline.py:405, in Pipeline.fit(self, X, y, **fit_params)
#     403     if self._final_estimator != "passthrough":
#     404         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     407 return self
#
# ...

# %% [markdown]
# # Linear model without pipeline

# %%
for col in X_train.columns:
    X_train[col] = np.log(X_train[col])
    X_test[col] = np.log(X_test[col], )
# Out:
# C:\Users\abhis\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
for col in ["CRIM", "ZN", "CHAS", "AGE", "DIS", "PTRATIO", "B", "LSTAT"]:
    X_train[col].replace([-np.inf, 0], [0, 1], inplace=True)
    X_test[col].replace([-np.inf, 0], [0, 1], inplace=True)

# %%
X_train.hist(bins=50, figsize=(12,8))
plt.tight_layout()

# %%
lreg = LinearRegression()

# %%
lreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
mean_squared_error(lreg.predict(X_test), y_test, squared=False)
# Out:
# 3.965440040315726
